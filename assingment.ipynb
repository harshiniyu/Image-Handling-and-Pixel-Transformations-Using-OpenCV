# %% [markdown]
# ##### import cv2
# import matplotlib.pyplot as plt

# %%
img = cv2.imread("Eagle.jpg")

# %%
img.shape
# Out:
# (600, 768, 3)

# %%
cv2.imshow('Imgae Window',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(img[:,:,::-1]);
plt.axis("off")
plt.title("original image")
img.shape
plt.show()

# %%
plt.imshow(img)
plt.title("Eagle")
plt.axis("on")
plt.show()

# %%
cv2.IMREAD_COLOR
# Out:
# 1

# %%
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
cv2.imshow("Grayscale Image", gray_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(img_line[:,:,::-1]);

# %%
img_copy=img.copy()

# %%
img_rgb = cv2.cvtColor(img_copy, cv2.COLOR_RGB2BGR)
plt.imshow(img_rgb)
plt.axis('off')
plt.show()

# %%
cr = img_rgb[0:450,200:550] 
plt.imshow(cr)
plt.title("Cropped image")
plt.axis("off")
plt.show()
cr.shape
# Out:
# (450, 350, 3)

# %%
cropped_region=img
